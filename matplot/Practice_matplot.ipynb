# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=[1,2,3]
y=[4,5,6]
plt.plot(x,y)
plt.grid()

# %%
plt.grid()

# %%
data={
    'salary':[4500,12500,52000,22000,26000,30000,23000,56000,89000,24780]

}
df=pd.DataFrame(data)
plt.plot(df['salary'])
plt.grid()

# %%
plt.plot(df['salary'],color='maroon')

# %%
plt.plot(df['salary'],color='maroon',marker='o')

# %%
plt.plot(df["salary"],color="red",marker="o",linestyle=":")

# %%
plt.hist(df["salary"])
# Out:
# (array([2., 0., 4., 1., 0., 1., 1., 0., 0., 1.]),
#  array([ 4500., 12950., 21400., 29850., 38300., 46750., 55200., 63650.,
#         72100., 80550., 89000.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['salary'],bins=5)
# Out:
# (array([2., 5., 1., 1., 1.]),
#  array([ 4500., 21400., 38300., 55200., 72100., 89000.]),
#  <BarContainer object of 5 artists>)

# %%
plt.boxplot(df['salary'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1741dcff590>,
#   <matplotlib.lines.Line2D at 0x1741dcff830>],
#  'caps': [<matplotlib.lines.Line2D at 0x1741dcffad0>,
#   <matplotlib.lines.Line2D at 0x1741dcffda0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1741dcff2c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1741dd24110>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1741dd243e0>],
#  'means': []}

# %%
df.loc[20]=[0]
df
# Out:
#     salary
# 0     4500
# 1    12500
# 2    52000
# 3    22000
# 4    26000
# 5    30000
# 6    23000
# 7    56000
# 8    89000
# 9    24780
# 20       0

# %%
plt.boxplot(df['salary'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1741dd70ce0>,
#   <matplotlib.lines.Line2D at 0x1741dd70fe0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1741dd712b0>,
#   <matplotlib.lines.Line2D at 0x1741dd71550>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1741dd70a40>],
#  'medians': [<matplotlib.lines.Line2D at 0x1741dd71850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1741dd71ac0>],
#  'means': []}
