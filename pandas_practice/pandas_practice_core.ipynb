# %%
import pandas as pd
s=pd.Series([1,2,3,4,5])
print(s)
s.dtype
s.values
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# array([1, 2, 3, 4, 5])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.name="numbers"
print(s.name)
s
# Out:
# numbers
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: numbers, dtype: int64

# %%
s.name="calories"
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: calories, dtype: int64

# %%
print(s.name)
# Out:
# calories

# %%
index=["apple","banana","grapes","strawberry","banana"]

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.0

# %%
print(s.iloc[3])
# Out:
# 4

# %%
s.index=index
print(s)
# Out:
# apple         1
# banana        2
# grapes        3
# strawberry    4
# banana        5
# Name: calories, dtype: int64

# %%
print(s["grapes"])
# Out:
# 3

# %%
print(s.loc["grapes"])
# Out:
# 3

# %%
print(s["apple":"strawberry"])
# Out:
# apple         1
# banana        2
# grapes        3
# strawberry    4
# Name: calories, dtype: int64

# %%
fruits_calories={
    "avacado":2.0,
    "pear":5.0,
    "peach":6.0,
    "guava":4.0,
    "cherry":8.0
}
fruit=pd.Series(fruits_calories,name="proteins")
fruit
# Out:
# avacado    2.0
# pear       5.0
# peach      6.0
# guava      4.0
# cherry     8.0
# Name: proteins, dtype: float64

# %%
fruit>3
# Out:
# avacado    False
# pear        True
# peach       True
# guava       True
# cherry      True
# Name: proteins, dtype: bool

# %%
fruit[fruit>3]
# Out:
# pear      5.0
# peach     6.0
# guava     4.0
# cherry    8.0
# Name: proteins, dtype: float64

# %%
#logical operators
[(fruit>3) & (fruit<5)]
# Out:
# [avacado    False
#  pear       False
#  peach      False
#  guava       True
#  cherry     False
#  Name: proteins, dtype: bool]

# %%
fruit[(fruit>3)&(fruit<=5)]
# Out:
# pear     5.0
# guava    4.0
# Name: proteins, dtype: float64

# %%
fruit[~(fruit>3)]
# Out:
# avacado    2.0
# Name: proteins, dtype: float64

# %%
s["avacado"]=5.5
s
# Out:
# apple         1.0
# banana        2.0
# grapes        3.0
# strawberry    4.0
# banana        5.0
# avacado       5.5
# Name: calories, dtype: float64

# %%
import numpy as np
ser=pd.Series([np.nan,1,np.nan,2])
ser.notnull().sum()
# Out:
# np.int64(2)

# %%
#data frame
data={
    "Name":["Alice","Bob","Charlie","David","Eve","Alice"],
    "Age":[25,30,35,np.nan,29,25],
    "Department":["HR","IT","Finance","IT","HR","HR"],
    "Salary":[50000,60000,70000,62000,np.nan,50000]
}
data
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Alice'],
#  'Age': [25, 30, 35, nan, 29, 25],
#  'Department': ['HR', 'IT', 'Finance', 'IT', 'HR', 'HR'],
#  'Salary': [50000, 60000, 70000, 62000, nan, 50000]}

# %%
df=pd.DataFrame(data)
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
df.head(3)
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0

# %%
df.tail(3)
# Out:
#     Name   Age Department   Salary
# 3  David   NaN         IT  62000.0
# 4    Eve  29.0         HR      NaN
# 5  Alice  25.0         HR  50000.0

# %%
df.iloc[1:3]
# Out:
#       Name   Age Department   Salary
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0

# %%
df.loc[1:3]
# Out:
#       Name   Age Department   Salary
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0

# %%
df.shape
# Out:
# (6, 4)

# %%
#df.drop("Age",axis=1,inplace=True)
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
df.info
# Out:
# <bound method DataFrame.info of       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0>

# %%
type(df)
print(df.describe())
# Out:
#              Age        Salary
# count   5.000000      5.000000
# mean   28.800000  58400.000000
# std     4.147288   8532.291603
# min    25.000000  50000.000000
# 25%    25.000000  50000.000000
# 50%    29.000000  60000.000000
# 75%    30.000000  62000.000000
# max    35.000000  70000.000000

# %%
df.loc[1:2,["Age","Department"]]
# Out:
#     Age Department
# 1  30.0         IT
# 2  35.0    Finance

# %%
df["Age"]
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3     NaN
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df.shape
# Out:
# (6, 4)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        6 non-null      str
#  1   Age         5 non-null      float64
#  2   Department  6 non-null      str
#  3   Salary      5 non-null      float64
# dtypes: float64(2), str(2)
# memory usage: 324.0 bytes

# %%
df.rename(columns={"Department":"Dept"},inplace=True)
df
# Out:
#       Name   Age     Dept   Salary
# 0    Alice  25.0       HR  50000.0
# 1      Bob  30.0       IT  60000.0
# 2  Charlie  35.0  Finance  70000.0
# 3    David   NaN       IT  62000.0
# 4      Eve  29.0       HR      NaN
# 5    Alice  25.0       HR  50000.0

# %%
df["Dept"].unique()
# Out:
# <StringArray>
# ['HR', 'IT', 'Finance']
# Length: 3, dtype: str

# %%
#value count
df["Dept"].value_counts()
# Out:
# Dept
# HR         3
# IT         2
# Finance    1
# Name: count, dtype: int64

# %%
df["promoted Salary"]=df["Salary"]*10
df
# Out:
#       Name   Age     Dept   Salary  promoted Salary
# 0    Alice  25.0       HR  50000.0         500000.0
# 1      Bob  30.0       IT  60000.0         600000.0
# 2  Charlie  35.0  Finance  70000.0         700000.0
# 3    David   NaN       IT  62000.0         620000.0
# 4      Eve  29.0       HR      NaN              NaN
# 5    Alice  25.0       HR  50000.0         500000.0

# %%
#count null values in a column
df.isnull().sum()
# Out:
# Name               0
# Age                1
# Dept               0
# Salary             1
# promoted Salary    1
# dtype: int64

# %%
df.dropna(how="any")
# Out:
#       Name   Age     Dept   Salary  promoted Salary
# 0    Alice  25.0       HR  50000.0         500000.0
# 1      Bob  30.0       IT  60000.0         600000.0
# 2  Charlie  35.0  Finance  70000.0         700000.0
# 5    Alice  25.0       HR  50000.0         500000.0

# %%
df.dropna(how="all")
# Out:
#       Name   Age     Dept   Salary  promoted Salary
# 0    Alice  25.0       HR  50000.0         500000.0
# 1      Bob  30.0       IT  60000.0         600000.0
# 2  Charlie  35.0  Finance  70000.0         700000.0
# 3    David   NaN       IT  62000.0         620000.0
# 4      Eve  29.0       HR      NaN              NaN
# 5    Alice  25.0       HR  50000.0         500000.0

# %%
df.fillna(0)
# Out:
#       Name   Age     Dept   Salary  promoted Salary
# 0    Alice  25.0       HR  50000.0         500000.0
# 1      Bob  30.0       IT  60000.0         600000.0
# 2  Charlie  35.0  Finance  70000.0         700000.0
# 3    David   0.0       IT  62000.0         620000.0
# 4      Eve  29.0       HR      0.0              0.0
# 5    Alice  25.0       HR  50000.0         500000.0

# %%
df["Age"].fillna(df["Age"].mean)
# Out:
# 0                                                 25.0
# 1                                                 30.0
# 2                                                 35.0
# 3    <bound method Series.mean of 0    25.0\n1    3...
# 4                                                 29.0
# 5                                                 25.0
# Name: Age, dtype: object

# %%
df["Salary"].ffill()
# Out:
# 0    50000.0
# 1    60000.0
# 2    70000.0
# 3    62000.0
# 4    62000.0
# 5    50000.0
# Name: Salary, dtype: float64

# %%
df["Age"].bfill()
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    29.0
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df["Name"].replace("Charlie","Rose")
# Out:
# 0    Alice
# 1      Bob
# 2     Rose
# 3    David
# 4      Eve
# 5    Alice
# Name: Name, dtype: str

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
dup=df[df.duplicated()]
dup
# Out:
#     Name   Age Dept   Salary  promoted Salary
# 5  Alice  25.0   HR  50000.0         500000.0

# %%
df_dup=df[df.duplicated(keep="first")]
df_dup
# Out:
# Empty DataFrame
# Columns: [Name, Age, Dept, Salary, promoted Salary]
# Index: []

# %%
df["promoted Salary"]=df["promoted Salary"].apply(lambda x:x/10 if x>600000 else x)
df
# Out:
#       Name   Age     Dept   Salary  promoted Salary
# 0    Alice  25.0       HR  50000.0          50000.0
# 1      Bob  30.0       IT  60000.0          60000.0
# 2  Charlie  35.0  Finance  70000.0           7000.0
# 3    David   NaN       IT  62000.0           6200.0
# 4      Eve  29.0       HR      NaN              NaN

# %%
df["Age"]=df["Age"].apply(lambda x:x*2 if x>25 else x)
df
# Out:
#       Name    Age     Dept   Salary  promoted Salary
# 0    Alice   25.0       HR  50000.0          50000.0
# 1      Bob  240.0       IT  60000.0          60000.0
# 2  Charlie  280.0  Finance  70000.0           7000.0
# 3    David    NaN       IT  62000.0           6200.0
# 4      Eve  232.0       HR      NaN              NaN

# %%
import pandas as pd
print(pd.Timestamp.today())
# Out:
# 2026-01-27 10:45:02.896673

# %%
print(pd.Timedelta(days=7))
# Out:
# 7 days 00:00:00

# %%
import pandas as pd

data = {
    'student_id': [1, 2, 3, 4, 5, 6, 7, 8, 9],
    'course_id':  ['C1', 'C2', 'C1', 'C3', 'C2', 'C3', 'C1', 'C2', 'C3'],
    'login_date': [
        '2026-01-25', '2026-01-20',
        '2026-01-10', '2026-01-05',
        '2026-01-26', '2026-01-18',
        '2026-01-02',
        '2026-01-24', '2026-01-23'
    ],
    'minutes_spent': [30, 45, 20, 50, 60, 40, 15, 35, 55]
}

df = pd.DataFrame(data)
print(df)
df['login_date']=pd.to_datetime(df['login_date'])
cutoff=pd.Timestamp('2026-01-27')-pd.Timedelta(days=7)
last_login=df.groupby('student_id')['login_date'].max().reset_index()
inactive=last_login[last_login['login_date']<cutoff]
print(inactive)
# Out:
#    student_id course_id  login_date  minutes_spent
# 0           1        C1  2026-01-25             30
# 1           2        C2  2026-01-20             45
# 2           3        C1  2026-01-10             20
# 3           4        C3  2026-01-05             50
# 4           5        C2  2026-01-26             60
# 5           6        C3  2026-01-18             40
# 6           7        C1  2026-01-02             15
# 7           8        C2  2026-01-24             35
# 8           9        C3  2026-01-23             55
#    student_id login_date
# 2           3 2026-01-10
# 3           4 2026-01-05
# 5           6 2026-01-18
# 6           7 2026-01-02
